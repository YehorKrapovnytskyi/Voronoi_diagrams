# %%
import torch
from torch.utils.data import DataLoader
import sys
import os
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
sys.path.append(os.path.abspath('../src/'))
from dataset_generator.VoronoiGenerator import VoronoiGenerator

# %%
dataset = VoronoiGenerator("../voronoi_data/voronoi_data.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 dataset = VoronoiDataset("../voronoi_data/voronoi_data.h5")
#
# NameError: name 'VoronoiDataset' is not defined

# %%
random.seed(5)
random_images_nums = random.sample(range(0, len(dataset)), 5)
random_images_nums

# %%
fig, ax = plt.subplots(5, 1, figsize=(10, 10), dpi=800)
for idx, i in enumerate(random_images_nums):
    image = dataset[i][0];
    image_permuted = image.permute(1, 2, 0);
    ax[idx].imshow(image_permuted);
    ax[idx].axis('off');

plt.tight_layout();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 fig, ax = plt.subplots(5, 1, figsize=(10, 10), dpi=800)
# ----> 2 for idx, i in enumerate(random_images_nums):
#       3     image = dataset[i][0];
#       4     image_permuted = image.permute(1, 2, 0);
#
# NameError: name 'random_images_nums' is not defined
